# %%
import random
import collections
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

client_id = '3860186b260d438ba9e591c673f3ed0e'
client_secret = '4de9330737a84c16ba946e312178bdd4'
redirect_uri = 'http://localhost/'
username = 'u2qt69mreoqsc16jar5z2s7cl'
scope = 'playlist-modify-public'
# auth_manager = SpotifyClientCredentials(client_id, client_secret)
auth_manager = SpotifyOAuth(client_id, client_secret, redirect_uri, \
                            username = username, scope = scope)
sp = spotipy.Spotify(auth_manager = auth_manager)

# %%
# EMILY
track_ids = [
    '4NKn506u7FeUTFRc9Sq688',
    '6aoGtdWXBkYQ2O2wnyIz2x',
    '676eXXtx6I7yxaDfXvMpjK',
    '558ywNDZY2pCMPgoAOxq4R',
    '50WeOnXhM1H7AZEeIDoWfZ'
]

# JACKIE
track_ids = [
    '2PkQeKapTNUjwpKLf8aJlq',
    '7ARveOiD31w2Nq0n5FsSf8',
    '4AuBmjPXmbBc0ZxFuaqcVQ',
    '0Do59HJNKcUliLc888Y2eT',
    '4djIFfof5TpbSGRZUpsTXq'
]

# ME
track_ids = [
    '07FkzikE6FuHIa8Ma7zJGc',
    '2deFH5zveEBEUuURpqTN3C',
    '2M9ULmQwTaTGmAdXaXpfz5',
    '5DqdesEfbRyOlSS3Tf6c29',
    '5kfNriitmkNE8mUbZ7gbq8'
]

# %%
def get_artist_ids(track_ids):
    artist_ids = set()
    for track_id in track_ids:
        result = sp.track(track_id)['artists']
        for artist in result:
            artist_ids.add(artist['id'])
    
    return list(artist_ids)


def get_related_artists(artist_id):
    related_artists = []
    result = sp.artist_related_artists(artist_id)['artists']
    for artist in result:
        related_artists.append(artist['id'])
    artists = set()
    # print(related_artists)
    try:
        artists.update(related_artists[:2])
        related_artists.sort(reverse = True, key = get_artist_popularity)
        artists.update(related_artists[:2])
        artists.update(random.sample(related_artists[3:], k = 2))
    except:
        return []
        
    return list(artists)


def get_top_tracks(artist_id):
    top_tracks = []
    result = sp.artist_top_tracks(artist_id)['tracks']
    for track in result:
        top_tracks.append(track['id'])
    tracks = set()
    try:
        tracks.update(random.sample(top_tracks[:5], k = 2))
        tracks.update(random.sample(top_tracks[6:], k = 3))
    except:
        tracks.update(top_tracks)
    
    return list(tracks)


def get_artist_popularity(artist_id):
    return sp.artist(artist_id)['popularity']

# %%
def get_recommended_tracks(track_ids):
    recommended_tracks = set()
    artist_ids = get_artist_ids(track_ids)
    for artist_id in artist_ids:
        related_artists = get_related_artists(artist_id)
        
        for artist in related_artists:
            top_tracks = get_top_tracks(artist)
            recommended_tracks.update(top_tracks)
            
    return random.sample(list(recommended_tracks), k = 100)

recommended_tracks = get_recommended_tracks(track_ids)
recommended_tracks
# Out:
# ['7oGZAicScQt96OAW4AruYy',
#  '2I88NEWpKrAPZuapXNV5G6',
#  '375m7A8TgZbBgvchmMySyw',
#  '1wYZZtamWTQAoj8B812uKQ',
#  '3pPRpc4h3EpfmPFlmRLa3w',
#  '57m2Kve0xnAgYVAPxMLKHS',
#  '5trr3oRHYaNEmbRp3NuAEP',
#  '0XBf3lA3mUwWmDk5bUOiZh',
#  '3doHXO2n8mAW8XkIFeapTZ',
#  '2RFt6ZWQbr9mPhsft9u9eX',
#  '1db6ixe9nX6cqt2V1DYZnW',
#  '0j5QKkgh58UmjjONmDxYhE',
#  '3DXdjHnePKnh6oXw2ZgGSl',
#  '7vO3KTA1YPgw6eb3NITrO3',
#  '5FWF91jFypdEYNZkRW9OnV',
#  '2smpiAZfaN0GFi15MqAq6E',
#  '5bZeugrr7oIATt1CLJuhT4',
#  '72PFP54TZ9Tpj9dYQcb46D',
#  '2G1tXoGBaEMJ7FKGnkf6ud',
#  '5ojAgSVQftPufiZK4w3SS5',
#  '2dHAkrR6F78HeEgogDThyd',
#  '6cSGSXvgioQxGQbM9VRe1G',
#  '61YzdCCBPM5Pc7lIiD5i8C',
#  '6H2wnX7ytNeCKERIVqCwgs',
#  '6pcghTFCRXW9yi9oSYYg86',
#  '60YqDe8UqfRaSFZ6TvPI9u',
#  '2U0zvszh4nKG92Q8TVnnhT',
#  '1irQqioH3g13sybtzD3jJL',
#  '6KOEK6SeCEZOQkLj5M1PxH',
#  '13bvtSeypl17SUsd7l76v5',
#  '6etuQn3IkhqFU8RA14b5US',
#  '4h7qcXBtaOJnmrapxoWxGf',
#  '6SkoBaMd0lzoQjID5aV2d9',
#  '3ntcm3V9ByPKN6cstxXh80',
#  '3w3y8KPTfNeOKPiqUTakBh',
#  '4mwuPJJJNtRLs7OLlUGXf2',
#  '3bfqkspKABT4pPicm6wC9F',
#  '2mtLGVN6xZm93wDG9nvviS',
#  '6LteLVcW0oWLjuW6nePyWb']

# %%
recommended_tracks[47]
# Out:
# '78wMD0pLwum3Xmm76VMQel'

# %%
df = pd.DataFrame(columns = [
    'energy',
    'valence',
    'speechiness',
    'acousticness',
    'danceability',
    'instrumentalness',
    'tempo'
])
track_audio_features = sp.audio_features(recommended_tracks)
for i in range(len(track_audio_features)):
    track = track_audio_features[i]
    df.loc[i] = [
        track['energy'],
        track['valence'],
        track['speechiness'],
        track['acousticness'],
        track['danceability'],
        track['instrumentalness'],
        track['tempo']
        
    ]
    
df
# Out:
#     energy  valence  speechiness  acousticness  danceability  \
# 0   0.6800    0.656       0.0629       0.00906         0.775
# 1   0.5530    0.620       0.1010       0.27400         0.605
# 2   0.0587    0.341       0.0763       0.95000         0.561
# 3   0.8210    0.331       0.1040       0.07850         0.376
# 4   0.6550    0.540       0.0983       0.10300         0.631
# ..     ...      ...          ...           ...           ...
# 95  0.6980    0.867       0.0431       0.04900         0.726
# 96  0.3960    0.260       0.3590       0.28600         0.868
# 97  0.8380    0.646       0.0513       0.13400         0.716
# 98  0.4570    0.494       0.0691       0.22400         0.548
# 99  0.1790    0.405       0.1090       0.61300         0.481
#
#     instrumentalness    tempo
# 0           0.000000  114.025
# 1           0.015200  152.076
# 2           0.000000  143.032
# 3           0.000000  120.462
# 4           0.000000   90.017
# ..               ...      ...
# 95          0.000000  143.994
# 96          0.000000  126.244
# 97          0.000000  130.034
# 98          0.000083  175.659
# 99          0.000028   74.850
#
# [100 rows x 7 columns]

# %%
#         -4.80072777e-01,  3.61488532e-01, -1.13862167e-01,
#          2.91144211e-01],
#        [-6.67928667e-01,  1.88137156e-01, -3.72537842e-01,
#         -1.51510155e-01, -8.87587431e-01, -1.08120189e-01,
#          1.98967624e+00],
#        [-2.00850212e+00, -1.84527750e-01,  8.82551364e-02,
#          1.26861051e+00, -1.38573082e+00, -1.11902165e-01,
#         -1.76325122e+00]])

# %%
df = pd.DataFrame(scaled_features)
pca = PCA(5)
pca_projection = pca.fit_transform(df)
df = pd.DataFrame(pca_projection)
df
# Out:
#            0         1         2         3         4
# 0  -1.242912 -0.669344 -0.283646  0.500644 -0.494393
# 1  -0.259851  0.164651  1.453464 -0.191886 -0.129297
# 2   3.202762  0.494270  0.684502 -0.876739 -1.251696
# 3   0.075266 -0.758131  0.548074 -0.381629  2.348722
# 4  -0.293911 -0.635109 -0.680405  0.805793  0.621828
# ..       ...       ...       ...       ...       ...
# 95 -1.597567 -1.140036  0.653728 -0.216098 -0.790521
# 96 -0.302062  2.986214 -1.584277 -0.693539 -0.336075
# 97 -1.313277 -0.886085  0.269085  0.023638 -0.163643
# 98  0.257237 -0.191718  1.583413 -1.517446 -0.197001
# 99  2.729910 -0.204719 -0.795469  0.829145  0.370184
#
# [100 rows x 5 columns]

# %%
clustering = KMeans(4)
clustering.fit(df)
predictions = clustering.predict(df)

# %%
predictions_counter = collections.Counter(predictions)
predictions_counter
# Out:
# Counter({0: 47, 3: 31, 1: 21, 2: 1})

# %%
tracks_by_cluster = {}
for i in range(len(predictions)):
    if(predictions[i] in tracks_by_cluster.keys()):
        tracks_by_cluster[predictions[i]].append(recommended_tracks[i])
    else:
        tracks_by_cluster[predictions[i]] = [recommended_tracks[i]]
tracks_by_cluster
# Out:
# {0: ['7oGZAicScQt96OAW4AruYy',
#   '2I88NEWpKrAPZuapXNV5G6',
#   '1wYZZtamWTQAoj8B812uKQ',
#   '3pPRpc4h3EpfmPFlmRLa3w',
#   '4ybRBrb9DmqnCpPcpEyBns',
#   '2vBjFu7yNWVfLDAy7gf6EN',
#   '5weJJZ5Xas6MkxxsLJatyt',
#   '7EAtZT0UPVVEQxi6SsmqIy',
#   '74nReXHbAko0DLmBniJest',
#   '65wnZsZLKJimfK1cTFOfa1',
#   '1bQhZOoXYqjXs7u7rFXo0h',
#   '3Vo4wInECJQuz9BIBMOu8i',
#   '4NiehSBQthimPzRsVeOgCT',
#   '55YqwT8BH8alblsZ10zVIO',
#   '3TXYRNSjz8txG5rL5H9RWO',
#   '7lozLnUfzcgEpMMVQI7yhA',
#   '3RDcUlLGp3SLp2AmUbUbls',
#   '4yJiXq86uM56uIfIZgE440',
#   '5PYQUBXc7NYeI1obMKSJK0',
#   '5BoIP8Eha5hwmRVURkC2Us',
#   '4pCUMrVlDuWIk6X03VDvT2',
#   '0KKkJNfGyhkQ5aFogxQAPU',
#   '7MqeeNEYUxb7JeFnaBSSwo',
#   '0Yj16EfuGCjbbv6W31pQwk',
#   '7s1SC0ymhSFkYtigMXu9Pe',
#   '5jNgANrdXUCECd7gIC5KLC',
#   '6hkOqJ5mE093AQf2lbZnsG',
#   '3doHXO2n8mAW8XkIFeapTZ',
#   '3DXdjHnePKnh6oXw2ZgGSl',
#   '2smpiAZfaN0GFi15MqAq6E',
#   '72PFP54TZ9Tpj9dYQcb46D',
#   '2G1tXoGBaEMJ7FKGnkf6ud',
#   '5ojAgSVQftPufiZK4w3SS5',
#   '6cSGSXvgioQxGQbM9VRe1G',
#   '61YzdCCBPM5Pc7lIiD5i8C',
#   '6H2wnX7ytNeCKERIVqCwgs',
#   '6pcghTFCRXW9yi9oSYYg86',
#   '60YqDe8UqfRaSFZ6TvPI9u',
#   '2U0zvszh4nKG92Q8TVnnhT',
#   '6KOEK6SeCEZOQkLj5M1PxH',
#   '13bvtSeypl17SUsd7l76v5',
#   '6etuQn3IkhqFU8RA14b5US',
#   '4h7qcXBtaOJnmrapxoWxGf',
#   '3ntcm3V9ByPKN6cstxXh80',
#   '3w3y8KPTfNeOKPiqUTakBh',
#   '3bfqkspKABT4pPicm6wC9F',
#   '2mtLGVN6xZm93wDG9nvviS'],
#  3: ['375m7A8TgZbBgvchmMySyw',
#   '57m2Kve0xnAgYVAPxMLKHS',
#   '1ugQtcwmKOXvKAYzhjncmv',
#   '6668ZaUUXqZ25Tb0DMr2HO',
#   '4JuZQeSRYJfLCqBgBIxxrR',
#   '6jA8HL9i4QGzsj6fjoxp8Y',
#   '3tZs3nVjySLbL320lP4mvs',
#   '0PUkanqCGTb6qseXPKOw1F',
#   '2gjELujyj9OFVQZzS7lgJH',
#   '4qAHuJq5T4Q97EQZG47H0P',
#   '6y6jbcPG4Yn3Du4moXaenr',
#   '69vToJ9BMbbLlFZo7k7A7B',
#   '5DTCKNnlpC94Ri2zX2IyS8',
#   '78wMD0pLwum3Xmm76VMQel',
#   '35AG36QH9ytiNtPyx9xwr8',
#   '4OBZT9EnhYIV17t4pGw7ig',
#   '7l97ElWmIdVHWUaOeeU5ZC',
#   '39jXnbACjiaiTwwhsr5sY5',
#   '30SomWM8c8uuaV0MFh5b8T',
#   '7iGfwZbCGLq9ExyMuOeMfN',
#   '7tOAtB2F50KXEkw86frba6',
#   '2NWVdwbd2hPIzC2lyf4y63',
#   '2RFt6ZWQbr9mPhsft9u9eX',
#   '1db6ixe9nX6cqt2V1DYZnW',
#   '0j5QKkgh58UmjjONmDxYhE',
#   '7vO3KTA1YPgw6eb3NITrO3',
#   '5FWF91jFypdEYNZkRW9OnV',
#   '5bZeugrr7oIATt1CLJuhT4',
#   '2dHAkrR6F78HeEgogDThyd',
#   '6SkoBaMd0lzoQjID5aV2d9',
#   '6LteLVcW0oWLjuW6nePyWb'],
#  1: ['5trr3oRHYaNEmbRp3NuAEP',
#   '0XBf3lA3mUwWmDk5bUOiZh',
#   '5J1yyAT28YsG72sbiHj2Xg',
#   '3NNPXSLp2aHYY8sD4q9Mhe',
#   '7r8lp6nukhNPK9QPC79k30',
#   '2vYlmJnqUuRV0Pg4M0IY5K',
#   '69fnnbeoZO9h16CUZGIbTG',
#   '1BZRU1HxYxJD0NFBrGk3C3',
#   '0U0L0evJAaT1nqAwyxAH1M',
#   '4KTtYhxFtFL7mBwnjkKfLm',
#   '0ZmwyiKzkayjwXkJaKG0Nw',
#   '0znCw9dSfsrBGUtxAzd9kD',
#   '26LuO7GNmYgv8hVVPh7HKA',
#   '7wBuTHeMvITB56U9cyVJc6',
#   '50xeLNGKmskmYUSINhqvfa',
#   '2rTnVB1bvwxHtaIl4uVu7f',
#   '7lKNg20fAXWXgrr9ZmVdEE',
#   '7DkU4AK9MFzKOJmmeLE4fc',
#   '4ys3qPP1YnF2IgEB2x8EOW',
#   '1irQqioH3g13sybtzD3jJL',
#   '4mwuPJJJNtRLs7OLlUGXf2'],
#  2: ['40ijlFtuamT3J2zR2mwfmm']}

# %%
predictions_counter.keys()
# Out:
# dict_keys([0, 3, 1, 2])

# %%
for key in list(predictions_counter.keys()):
    if(predictions_counter[key] < 10):
        del predictions_counter[key]
        
len(predictions_counter.keys())
# Out:
# 3

# %%
recommended_30_songs = []
num_songs = int(30 / len(predictions_counter.keys()))
print(num_songs)
for key in predictions_counter.keys():
    recommended_30_songs.extend(random.sample(tracks_by_cluster[key], k = num_songs))
                               
recommended_30_songs
# Out:
# 10
# ['61YzdCCBPM5Pc7lIiD5i8C',
#  '2mtLGVN6xZm93wDG9nvviS',
#  '3bfqkspKABT4pPicm6wC9F',
#  '13bvtSeypl17SUsd7l76v5',
#  '4NiehSBQthimPzRsVeOgCT',
#  '72PFP54TZ9Tpj9dYQcb46D',
#  '3pPRpc4h3EpfmPFlmRLa3w',
#  '6H2wnX7ytNeCKERIVqCwgs',
#  '4pCUMrVlDuWIk6X03VDvT2',
#  '6cSGSXvgioQxGQbM9VRe1G',
#  '7tOAtB2F50KXEkw86frba6',
#  '35AG36QH9ytiNtPyx9xwr8',
#  '30SomWM8c8uuaV0MFh5b8T',
#  '4JuZQeSRYJfLCqBgBIxxrR',
#  '6SkoBaMd0lzoQjID5aV2d9',
#  '375m7A8TgZbBgvchmMySyw',
#  '1ugQtcwmKOXvKAYzhjncmv',
#  '4OBZT9EnhYIV17t4pGw7ig',
#  '0PUkanqCGTb6qseXPKOw1F',
#  '6LteLVcW0oWLjuW6nePyWb',
#  '69fnnbeoZO9h16CUZGIbTG',
#  '4mwuPJJJNtRLs7OLlUGXf2',
#  '50xeLNGKmskmYUSINhqvfa',
#  '3NNPXSLp2aHYY8sD4q9Mhe',
#  '2vYlmJnqUuRV0Pg4M0IY5K',
#  '4ys3qPP1YnF2IgEB2x8EOW',
#  '5trr3oRHYaNEmbRp3NuAEP',
#  '1BZRU1HxYxJD0NFBrGk3C3',
#  '0U0L0evJAaT1nqAwyxAH1M',
#  '7r8lp6nukhNPK9QPC79k30']

# %%
len(recommended_30_songs)
# Out:
# 30

# %%
sp.user_playlist_add_tracks(
    user = 'u2qt69mreoqsc16jar5z2s7cl',
    playlist_id = '6RMt9XC9bE5jYjATISLVft',
    tracks = list(recommended_30_songs)
)
# Out:
# {'snapshot_id': 'MiwzOTMzYzViMDA4NTc4MWI4YWU2NmI2N2Y3ODBkODcyY2IwYTUwYzg3'}
